# %% [markdown]
# # Header 1

# %% [markdown]
# ## Header 2

# %% [markdown]
# ###### Header 3

# %% [markdown]
# x = 10
# print(x)

# %% [markdown]
# **This is an *example* of Bold**

# %% [markdown]
# python methods:
# - append()
# - extend()
